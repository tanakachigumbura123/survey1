# %%
import pandas as pd
import numpy as np
import os
from  matplotlib import pyplot as plt

# %%
data=pd.read_excel(r"C:\Users\Tanaka\Desktop\Attachment\New folder\Dataset.xlsx")

# %%
data
# Out:
#     consent section_1_1 section_1_2 section_1_3  section_1_4 section_1_5  \
# 0       Yes      Matobo      Ward 4      Female         21.0         Yes
# 1       Yes      Matobo      Ward 4      Female         26.0          No
# 2       Yes      Matobo      Ward 4      Female         29.0         Yes
# 3       Yes      Matobo      Ward 4      Female         30.0          No
# 4       Yes      Matobo      Ward 4      Female         30.0         Yes
# ..      ...         ...         ...         ...          ...         ...
# 313     Yes      Mutasa     Ward 19        Male         27.0         Yes
# 314     Yes      Mutasa     Ward 19        Male         32.0         Yes
# 315     Yes      Mutasa     Ward 19      Female         23.0          No
# 316     Yes      Mutasa     Ward 19      Female         26.0          No
# 317     Yes      Mutasa     Ward 19      Female         27.0          No
#
#             section_1_6 section_1_6_other     section_1_7  \
# ...

# %%
data.isnull().sum()
# Out:
# consent            0
# section_1_1        2
# section_1_2        2
# section_1_3        2
# section_1_4        2
#                 ...
# _notes           318
# _version           0
# _duration        318
# _submitted_by      1
# _xform_id          0
# Length: 111, dtype: int64

# %%
data.describe()
# Out:
#        section_1_4  section_2_9a  section_2_9b  \
# count   316.000000    202.000000    202.000000
# mean     25.579114     73.321782    192.089109
# std       4.490209     83.857973    117.824864
# min      17.000000      0.000000      0.000000
# 25%      22.000000     16.250000    100.000000
# 50%      25.000000     50.000000    175.000000
# 75%      29.000000     93.750000    250.000000
# max      36.000000    500.000000    580.000000
#
#        section_3_5.Private sector internship  \
# count                             318.000000
# mean                                0.481132
# std                                 0.500431
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 1.000000
# max                                 1.000000
#
#        section_3_5.Peer to peer training  \
# count                         318.000000
# ...

# %%
pd.DataFrame(data["section_1_1"])
# Out:
#     section_1_1
# 0        Matobo
# 1        Matobo
# 2        Matobo
# 3        Matobo
# 4        Matobo
# ..          ...
# 313      Mutasa
# 314      Mutasa
# 315      Mutasa
# 316      Mutasa
# 317      Mutasa
#
# [318 rows x 1 columns]

# %%
data1=data.rename(columns={"section_1_1":"DISTRICT",
                          "section_1_2":"WARD",
                          "section_1_3":"GENDER",
                          "section_1_4":"AGE",
                          "section_1_5":"HOUSEHOLD HEAD",
                          "section_1_6":"RELIGION",
                          "section_1_6_other":"Other",
                          "section_1_7":"EDUCATION",
                          "section_1_8":"MARITAL STATUS"})
data1
# Out:
#     consent DISTRICT     WARD  GENDER   AGE HOUSEHOLD HEAD  \
# 0       Yes   Matobo   Ward 4  Female  21.0            Yes
# 1       Yes   Matobo   Ward 4  Female  26.0             No
# 2       Yes   Matobo   Ward 4  Female  29.0            Yes
# 3       Yes   Matobo   Ward 4  Female  30.0             No
# 4       Yes   Matobo   Ward 4  Female  30.0            Yes
# ..      ...      ...      ...     ...   ...            ...
# 313     Yes   Mutasa  Ward 19    Male  27.0            Yes
# 314     Yes   Mutasa  Ward 19    Male  32.0            Yes
# 315     Yes   Mutasa  Ward 19  Female  23.0             No
# 316     Yes   Mutasa  Ward 19  Female  26.0             No
# 317     Yes   Mutasa  Ward 19  Female  27.0             No
#
#                RELIGION Other       EDUCATION           MARITAL STATUS  ...  \
# 0          Christianity   NaN  Ordinary Level  Married living together  ...
# 1          Christianity   NaN  Ordinary Level  Married living together  ...
# ...

# %%
data1.isnull().sum()
# Out:
# consent            0
# DISTRICT           2
# WARD               2
# GENDER             2
# AGE                2
#                 ...
# _notes           318
# _version           0
# _duration        318
# _submitted_by      1
# _xform_id          0
# Length: 111, dtype: int64

# %%
data2=data1.fillna(method="pad")
data2
# Out:
#     consent DISTRICT     WARD  GENDER   AGE HOUSEHOLD HEAD  \
# 0       Yes   Matobo   Ward 4  Female  21.0            Yes
# 1       Yes   Matobo   Ward 4  Female  26.0             No
# 2       Yes   Matobo   Ward 4  Female  29.0            Yes
# 3       Yes   Matobo   Ward 4  Female  30.0             No
# 4       Yes   Matobo   Ward 4  Female  30.0            Yes
# ..      ...      ...      ...     ...   ...            ...
# 313     Yes   Mutasa  Ward 19    Male  27.0            Yes
# 314     Yes   Mutasa  Ward 19    Male  32.0            Yes
# 315     Yes   Mutasa  Ward 19  Female  23.0             No
# 316     Yes   Mutasa  Ward 19  Female  26.0             No
# 317     Yes   Mutasa  Ward 19  Female  27.0             No
#
#                RELIGION   Other       EDUCATION           MARITAL STATUS  ...  \
# 0          Christianity     NaN  Ordinary Level  Married living together  ...
# 1          Christianity     NaN  Ordinary Level  Married living together  ...
# ...

# %%
data2.isnull().sum()
# Out:
# consent            0
# DISTRICT           0
# WARD               0
# GENDER             0
# AGE                0
#                 ...
# _notes           318
# _version           0
# _duration        318
# _submitted_by      1
# _xform_id          0
# Length: 111, dtype: int64

# %%
pd.DataFrame(data2["_notes"])
# Out:
#      _notes
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 313     NaN
# 314     NaN
# 315     NaN
# 316     NaN
# 317     NaN
#
# [318 rows x 1 columns]

# %%
data2.fillna(value=0)
# Out:
#     consent DISTRICT     WARD  GENDER   AGE HOUSEHOLD HEAD  \
# 0       Yes   Matobo   Ward 4  Female  21.0            Yes
# 1       Yes   Matobo   Ward 4  Female  26.0             No
# 2       Yes   Matobo   Ward 4  Female  29.0            Yes
# 3       Yes   Matobo   Ward 4  Female  30.0             No
# 4       Yes   Matobo   Ward 4  Female  30.0            Yes
# ..      ...      ...      ...     ...   ...            ...
# 313     Yes   Mutasa  Ward 19    Male  27.0            Yes
# 314     Yes   Mutasa  Ward 19    Male  32.0            Yes
# 315     Yes   Mutasa  Ward 19  Female  23.0             No
# 316     Yes   Mutasa  Ward 19  Female  26.0             No
# 317     Yes   Mutasa  Ward 19  Female  27.0             No
#
#                RELIGION   Other       EDUCATION           MARITAL STATUS  ...  \
# 0          Christianity       0  Ordinary Level  Married living together  ...
# 1          Christianity       0  Ordinary Level  Married living together  ...
# ...

# %%
data2.isnull().sum()
# Out:
# consent            0
# DISTRICT           0
# WARD               0
# GENDER             0
# AGE                0
#                 ...
# _notes           318
# _version           0
# _duration        318
# _submitted_by      1
# _xform_id          0
# Length: 111, dtype: int64

# %% [markdown]
# # Table

# %%
data3=data2[[ 'DISTRICT','GENDER','AGE']]
data3
# Out:
#     DISTRICT  GENDER   AGE
# 0     Matobo  Female  21.0
# 1     Matobo  Female  26.0
# 2     Matobo  Female  29.0
# 3     Matobo  Female  30.0
# 4     Matobo  Female  30.0
# ..       ...     ...   ...
# 313   Mutasa    Male  27.0
# 314   Mutasa    Male  32.0
# 315   Mutasa  Female  23.0
# 316   Mutasa  Female  26.0
# 317   Mutasa  Female  27.0
#
# [318 rows x 3 columns]

# %%
import seaborn as sns

# %%
sns.countplot(data3["DISTRICT"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='DISTRICT', ylabel='count'>

# %%
data2.columns
# Out:
# Index(['consent', 'DISTRICT', 'WARD', 'GENDER', 'AGE', 'HOUSEHOLD HEAD',
#        'RELIGION', 'Other', 'EDUCATION', 'MARITAL STATUS',
#        ...
#        '_submission_time', '_index', '_parent_table_name', '_parent_index',
#        '_tags', '_notes', '_version', '_duration', '_submitted_by',
#        '_xform_id'],
#       dtype='object', length=111)

# %%
sns.countplot(data3["GENDER"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='GENDER', ylabel='count'>

# %%
sns.countplot(data3["AGE"])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='AGE', ylabel='count'>

# %%
sns.countplot(data3["GENDER"],["AGE"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10788/4234159018.py in <module>
# ----> 1 sns.countplot(data3["GENDER"],["AGE"])
#
# NameError: name 'sns' is not defined
